# %%
import pandas as pd
import numpy as np
from env import get_db_url

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# 1-3. Completed to do the following problems.

# %% [markdown]
# 4. Use your function to obtain a connection to the employees database.

# %%
query = '''
SELECT *
FROM departments
LIMIT 10'''

departments = pd.read_sql(query, get_db_url('employees'))
departments.head(5)
# Out:
#   dept_no         dept_name
# 0    d009  Customer Service
# 1    d005       Development
# 2    d002           Finance
# 3    d003   Human Resources
# 4    d001         Marketing

# %% [markdown]
# 5a. Intentionally make a type in the database url.  What kind of error message do you see?

# %%
query = '''
SELECT *
FROM departments
LIMIT 10'''

url = 'mysql+pymysql://Jemison_4444:987yg478349894d489@123.456.123.456/employees'

departments = pd.read_sql(query, url)
departments
# Ran then reset due to length of error message:

# %%
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '123.456.123.456' ([Errno 8] nodename nor servname provided, or not known)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# 5b. Intentionally make an error in your SQL query.  What does your error message look like?

# %%
query = '''
SELECT *
FROM deportments
LIMIT 10'''

departments = pd.read_sql(query, get_db_url('employees'))
departments
# Ran then reset due to length of error message:

# %%
# ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'employees.deportments' doesn't exist")
# [SQL: 
# SELECT *
# FROM deportments
# LIMIT 10]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# 6-8.

# %%
query = '''
SELECT *
FROM employees
'''

employees = pd.read_sql(query, get_db_url('employees'))
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
query = '''
SELECT *
FROM titles
'''

titles = pd.read_sql(query, get_db_url('employees'))
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
query = '''
SELECT DISTINCT title
FROM titles
'''

distinct_titles = pd.read_sql(query, get_db_url('employees'))
len(distinct_titles)
# Out:
# 7

# %%
# Can also use:
len(titles.title.unique())
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
query = '''
SELECT MIN(to_date) AS "Oldest To Date"
FROM titles
'''

min_to_date = pd.read_sql(query, get_db_url('employees'))
min_to_date
# Out:
#   Oldest To Date
# 0     1985-03-01

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
query = '''
SELECT MAX(to_date) AS "Most Recent to Date"
FROM titles
WHERE to_date != '9999-01-01'
'''

max_to_date = pd.read_sql(query, get_db_url('employees'))
max_to_date
# Out:
#   Most Recent to Date
# 0          2002-08-01

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# 1. Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, how = 'right', left_on = 'role_id', right_on = 'id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, how = 'outer', left_on = 'role_id', right_on = 'id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.merge(roles, left_on = 'id', right_on = 'id', how = "inner")
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter

# %%
# They all return mismatched joined data.

# %% [markdown]
# 5. Load the mpg dataset from PyDataset

# %%
from pydataset import data
mpg = data('mpg')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
# Honestly, they all look fine to me.  Could always turn abbreviations to full name if one likes, i.e. mpg.rename = {'cty':'city', 'drv':'drive_type'}

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe(include = 'all').T
# Out:
#               count unique          top freq       mean       std     min  \
# manufacturer    234     15        dodge   37        NaN       NaN     NaN
# model           234     38  caravan 2wd   11        NaN       NaN     NaN
# displ         234.0    NaN          NaN  NaN   3.471795  1.291959     1.6
# year          234.0    NaN          NaN  NaN     2003.5  4.509646  1999.0
# cyl           234.0    NaN          NaN  NaN   5.888889  1.611534     4.0
# trans           234     10     auto(l4)   83        NaN       NaN     NaN
# drv             234      3            f  106        NaN       NaN     NaN
# cty           234.0    NaN          NaN  NaN  16.858974  4.255946     9.0
# hwy           234.0    NaN          NaN  NaN  23.440171  5.954643    12.0
# fl              234      5            r  168        NaN       NaN     NaN
# class           234      7          suv   62        NaN       NaN     NaN
#
#                  25%     50%     75%     max
# ...

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
len(mpg.groupby('manufacturer').count())
# Out:
# 15

# %%
# also: mpg.manufacturer.nunique()

# %% [markdown]
# 11. How many different models are there?

# %%
len(mpg.groupby('model').count())
# Out:
# 38

# %%
# same as above: mpg.model.nunique()

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.cty
mpg.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference
# 1                  11
# 2                   8
# 3                  11
# 4                   9
# 5                  10

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.hwy + mpg.cty)/2
mpg.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    mileage_difference  average_mileage
# 1                  11             23.5
# 2                   8             25.0
# 3                  11             25.5
# 4                   9             25.5
# 5                  10             21.0

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.contains('auto')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# ...

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.mean().sort_values(ascending = False)
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic').average_mileage.mean().sort_values(ascending = False)
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %%
# better would be to use an np.where to create an automatic or manual category and then build this groupby result off of that.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
query = '''
SELECT *
FROM orders
'''

orders = pd.read_sql(query, get_db_url('chipotle'))
orders.head(10)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
# 5   6         3         1                           Chicken Bowl
# 6   7         3         1                          Side of Chips
# 7   8         4         1                          Steak Burrito
# 8   9         4         1                       Steak Soft Tacos
# 9  10         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                nan     $2.39
# 1                                       [Clementine]     $3.39
# ...

# %% [markdown]
# 2. What is the total price for each order?

# %%
orders.item_price = orders.item_price.str.replace('$','').astype(float)

orders.groupby('order_id').item_price.sum()
# Out:
# /var/folders/nw/8yyyyp8n70vbplhdsylyqs8c0000gn/T/ipykernel_79076/903297737.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders.item_price = orders.item_price.str.replace('$','').astype(float)
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
orders.groupby('item_name').quantity.sum().nlargest(n=3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
orders.groupby('item_name').item_price.sum().nlargest(n=1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
query = '''
SELECT *
FROM employees JOIN titles USING(emp_no)
'''

employee_title = pd.read_sql(query, get_db_url('employees'))
employee_title.head(5)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#
#              title   from_date     to_date
# 0  Senior Engineer  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01
# 4  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
employee_title.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
query = '''
SELECT departments.dept_name, titles.title 
FROM departments JOIN dept_emp USING(dept_no) 
JOIN titles USING(emp_no)
'''

title_and_dept = pd.read_sql(query, get_db_url('employees'))
title_and_dept.head(5)
# Out:
#           dept_name         title
# 0  Customer Service         Staff
# 1  Customer Service  Senior Staff
# 2  Customer Service         Staff
# 3  Customer Service  Senior Staff
# 4  Customer Service         Staff

# %%
pd.crosstab(title_and_dept.dept_name, title_and_dept.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           13925  16150               309
# Development                 1247   1424              7683
# ...
